# %%
import numpy as np
import networkx as nx
from treeApproximation import TreeApproximator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
m = np.random.rand(10,10)
g = nx.from_numpy_matrix(m)
nx.draw_networkx(g)

# %%
t = TreeApproximator(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c96ef50e0602> in <module>()
# ----> 1 t = TreeApproximator(g)
#
# ~/Desktop/final project/CS6820Project/treeApproximation.py in __init__(self, G)
#      47     def __init__(self, G: nx.Graph):
#      48         self.G = G
# ---> 49         self.spanning_tree_aprox: ComTreeNode = self._create_spanning_tree_approx()
#      50
#      51     def _distance_dict(self, node_list):
#
# ~/Desktop/final project/CS6820Project/treeApproximation.py in _create_spanning_tree_approx(self)
#      70         beta = _beta()
#      71
# ---> 72         diameter = max(map(lambda x: max(x.values()), node_dists.values()))
#      73
#      74         delta = np.log2(diameter)
#
# AttributeError: 'list' object has no attribute 'values'
